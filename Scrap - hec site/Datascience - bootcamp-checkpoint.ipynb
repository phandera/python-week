# %%
import pandas as pd
import html5lib
from bs4 import BeautifulSoup
import requests

# %%
url="https://hec.ac.mw/scholarships"

# %%
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Scholarship Opportunities | Higher Education Central Malawi
#   </title>
#   <meta content="" name="description"/>
#   <meta content="" name="title"/>
#   <meta content="HEC Media" name="author"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Higher Education Central Malawi" name="generator"/>
#   <link href="https://hec.ac.mw/themes/hec/assets/images/favicon.ico" rel="icon" type="image/ico"/>
#   <link href="https://hec.ac.mw/themes/hec/assets/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://hec.ac.mw/themes/hec/assets/css/normalize.css" rel="stylesheet"/>
#   <link href="https://hec.ac.mw/themes/hec/assets/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="https://hec.ac.mw/themes/hec/assets/css/icomoon.css" rel="stylesheet"/>
#   <link href="https://hec.ac.mw/themes/hec/assets/css/animate.css" rel="stylesheet"/>
# ...

# %%
#block = soup.find('p', class_ = 'scholar-meta')
#block
# Out:
# <p class="scholar-meta">
#                                   <i class="fa fa-pencil"></i> Posted on 18 October 2021 by HEC Media
#                                 </p>

# %%
blocks = soup.find_all('div', class_ = 'scholar-content-box')
block2 = soup.find('div', class_ = 'scholar-content-box').find_all('p')
block2[2].text
#block.text
# Out:
# '\n                                Malawi Wellcome Trust Pre-MSC and Pre-PhD Internship Scholarship. Closes 01 November 2021                   \n                                '

# %%
dates=[]
scholarships=[]
close_date=[]
for block in blocks :
    dates.append(block.find('p', {'class':'scholar-meta'}).text.replace('Posted on ','').replace(' by HEC Media','').strip())
    scholarships.append(block.find('h4', {'class':'scholarship-title'}).text.strip())
    close_date.append(block.find_all('p')[2].text.strip().split("Closes ")[1])
    
    df=pd.DataFrame({"Posted date":dates,"Scholarship":scholarships,"Deadline":close_date})

# %%
df
# Out:
#          Posted date                                        Scholarship  \
# 0    18 October 2021  Malawi Wellcome Trust Pre-MSC and Pre-PhD Inte...
# 1    13 October 2021  University of Oslo NORAD’s NORHED II  PhD and ...
# 2  22 September 2021  Nutrition 4 Health Activity Scholarship Opport...
# 3  15 September 2021     The Global Learning Scholarship Program (GLSP)
# 4     25 August 2021  The Schlumberger Foundation Faculty for the Fu...
# 5     11 August 2021  Kalinga Institute of Industrial Technology (KI...
# 6     10 August 2021  African Scientific, Research and Innovation Co...
# 7     10 August 2021               The Ashinaga African Initiative 2022
# 8       14 July 2021  PhD and Postdoc Positions in Machine Learning ...
#
#            Deadline
# 0  01 November 2021
# 1  05 November 2021
# 2   04 October 2021
# 3  16 December 2021
# 4  05 November 2021
# 5    15 August 2021
# 6      31 July 2021
# 7   28 January 2022
# 8    23 August 2021
